# %%
f=open("demo.txt","r")
print(f.read(15))
f.close()
# Out:
# A quick brown f

# %%
f=open("demo.txt","r")
print(f.readlines())
f.close()
# Out:
# ['A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n']

# %%
f=open("demo.txt","r")
print(f.readlines())
f.close()
# Out:
# ['A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n', 'A quick brown fox jumps over the lazy dog.\n']

# %%
#Read the file line by line
f=open("demo.txt","r")
l=0
for x in f:
    print(x)
    l+=1
print("Total number of lines : ",l)
f.close()
# Out:
# A quick brown fox jumps over the lazy dog.
#
# A quick brown fox jumps over the lazy dog.
#
# A quick brown fox jumps over the lazy dog.
#
# A quick brown fox jumps over the lazy dog.
#
# A quick brown fox jumps over the lazy dog.
#
# A quick brown fox jumps over the lazy dog.
#
# A quick brown fox jumps over the lazy dog.
#
# Total number of lines :  7

# %%
file=open("Write.txt","w")
file.write("The big bang\n")
f.close()

# %%
file=open("write.txt","a")
file.write("The universe is created")
f.close()

# %%
#delete a file
import os
if os.path.exists("guilty.txt"):
                  os.remove("guilty.txt")
                  print("File deleted")
else:
    print("file doesnt exist")
# Out:
# file doesnt exist

# %%
#illlustrate split() function.
path="demo.txt"
with open(path,"r") as file:
    data=file.readlines()
    for line in data:
        word=line.split()
        print(word)
# Out:
# ['A', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog.']
# ['A', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog.']
# ['A', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog.']
# ['A', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog.']
# ['A', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog.']
# ['A', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog.']
# ['A', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog.']

# %%
#panda
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
import pandas as pd
mydataset={
    'cars': ["redbull","mclaren","mercedes","ferrari,"],
    'tractor' : ["wiliams","audi","astonmartin","cadillac"]
}
myvar=pd.DataFrame(mydataset)
print(myvar)
# Out:
#        cars      tractor
# 0   redbull      wiliams
# 1   mclaren         audi
# 2  mercedes  astonmartin
# 3  ferrari,     cadillac

# %%
a=[1,7,2]
myvar=pd.Series(a,index=["sl.no","marks","AM"])
print(myvar)
# Out:
# sl.no    1
# marks    7
# AM       2
# dtype: int64

# %%
#create a series from dictionary
calories={"day1":420,"day2":380,"day3":370}
myvar= pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    370
# dtype: int64

# %%
#create series using data from day 2 and 3
calories={"day1":420,"day2":380,"day3":370}
myvar= pd.Series(calories,index=["day2","day3"])
print(myvar)
# Out:
# day2    380
# day3    370
# dtype: int64

# %%
#pandas data frame
data={
    "calories":[120,230,340],
    "days":[2,4,6],
    "duration":[15,30,45]
}
df= pd.DataFrame(data)
print(df)
# Out:
#    calories  days  duration
# 0       120     2        15
# 1       230     4        30
# 2       340     6        45

# %%
df=pd.read_csv("flower_dataset.csv")
print(df)
# Out:
#               species    size fragrance  height_cm
# 0                rose  medium      mild      48.55
# 1     shoeblack plant  medium      mild     147.07
# 2     shoeblack plant  medium      none     102.93
# 3            hibiscus   large      none     184.00
# 4     shoeblack plant   large      mild      83.07
# ...               ...     ...       ...        ...
# 9995         hibiscus   large      none     109.52
# 9996  shoeblack plant  medium      mild     145.23
# 9997         hibiscus   large      none     126.69
# 9998  shoeblack plant   large      none      77.62
# 9999             rose  medium      mild      88.11
#
# [10000 rows x 4 columns]

# %%
print(df.to_string())
# Out:
#               species    size fragrance  height_cm
# 0                rose  medium      mild      48.55
# 1     shoeblack plant  medium      mild     147.07
# 2     shoeblack plant  medium      none     102.93
# 3            hibiscus   large      none     184.00
# 4     shoeblack plant   large      mild      83.07
# 5            hibiscus   large      none     120.88
# 6                rose   small      mild      99.24
# 7                rose   small    strong      96.75
# 8            hibiscus   large      none     160.88
# 9     shoeblack plant   large      mild      60.43
# 10               rose   small    strong      37.00
# 11               rose   small    strong      68.56
# 12           hibiscus   large      none     147.55
# 13           hibiscus   large      none     123.01
# 14               rose   small      mild      46.21
# 15    shoeblack plant  medium      none     101.99
# 16               rose  medium    strong      33.10
# ...

# %%
#write a dataframe in csv and read its content
df=pd.DataFrame({'name':['ajay','vijay','sujal'],
                'course':['eng','bio','bsc'],
                'location':['delhi','mumbai','kolkata']})
df.to_csv(r'sd.csv')
df=pd.read_csv('sd.csv')
print(df)
# Out:
#    Unnamed: 0   name course location
# 0           0   ajay    eng    delhi
# 1           1  vijay    bio   mumbai
# 2           2  sujal    bsc  kolkata

# %%
df=pd.DataFrame({'name':['ajay','vijay','sujal'],
                'course':['eng','bio','bsc'],
                'location':['delhi','mumbai','kolkata']})
#telling what method to use and which file to compress
compression_opts=dict(method='zip',archive_name='a.csv')
#specifying the zip (a.zip), compression=whatevere given above
df.to_csv(r'a.zip',index=False,compression=compression_opts)

# %%
#TASK(to be done and submitted on next lab)
1.extract a zip file
2.read a csv file form a url
3.read an image from a url

# %%
path="img.jpg"
import matplotlib.pyplot as plt
import matplotlib.image as img
Image=img.imread(path)
plt.imshow(image)
print(Image.shape)
